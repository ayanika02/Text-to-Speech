# %%
pip install gTTS
# Out:
# ...
#
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\diya\anaconda3\lib\site-packages)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.simplilearn.com/web-development-interview-questions-article'  # Replace with the target URL
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react@18.2.0/umd/react.production.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react-dom@18.2.0/umd/react-dom.production.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdnjs.cloudflare.com/ajax/libs/redux/4.2.1/redux.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdn.jsdelivr.net/npm/react-redux@8.0.5/dist/react-redux.min.js"> </script>
# <!-- Global site tag (gtag.js) - Google Analytics 4 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-CG9EYRX7VL"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
# ...

# %%
ques = soup.find_all('h3')

# %%
ques
# Out:
# [<h3>Section-I. Top Web Developer Interview Questions for Freshers</h3>,
#  <h3>Section-II. Web Developer Interview Questions for Experienced Web DevelopersÂ </h3>,
#  <h3>Interview Questions for MEAN Stack Developer</h3>,
#  <h3>FAQs</h3>,
#  <h3>Get Started: Become a Full-Stack Web Developer in 9 Months!</h3>,
#  <h3>Section-I. Top Web Developer Interview Questions for Freshers</h3>,
#  <h3>Section-II. Web Developer Interview Questions for Experienced Web DevelopersÂ </h3>,
#  <h3>Interview Questions for MEAN Stack Developer</h3>,
#  <h3>FAQs</h3>,
#  <h3>Get Started: Become a Full-Stack Web Developer in 9 Months!</h3>,
#  <h3>1. What skills should a good Web Developer have?</h3>,
#  <h3>2. Are you aware of the roles and responsibilities of a Web Developer?</h3>,
#  <h3>3. What are the added benefits of HTTP/2 compared to HTTP 1.1?</h3>,
#  <h3>4. Can you list a few ways to speed up Page Loading?</h3>,
#  <h3>5. How is XHTML different from HTML?</h3>,
# ...

# %%
questions = [p.get_text() for p in ques]

# %%
questions
# Out:
# ['Section-I. Top Web Developer Interview Questions for Freshers',
#  'Section-II. Web Developer Interview Questions for Experienced Web DevelopersÂ\xa0',
#  'Interview Questions for MEAN Stack Developer',
#  'FAQs',
#  'Get Started: Become a Full-Stack Web Developer in 9 Months!',
#  'Section-I. Top Web Developer Interview Questions for Freshers',
#  'Section-II. Web Developer Interview Questions for Experienced Web DevelopersÂ\xa0',
#  'Interview Questions for MEAN Stack Developer',
#  'FAQs',
#  'Get Started: Become a Full-Stack Web Developer in 9 Months!',
#  '1. What skills should a good Web Developer have?',
#  '2. Are you aware of the roles and responsibilities of a Web Developer?',
#  '3. What are the added benefits of HTTP/2 compared to HTTP 1.1?',
#  '4. Can you list a few ways to speed up Page Loading?',
#  '5. How is XHTML different from HTML?',
#  '6. Explain Webpack.',
# ...

# %%
import re

# %%
ques = [item for item in questions if re.match(r'^\d+\.\s', item)]

# %%
ques
# Out:
# ['1. What skills should a good Web Developer have?',
#  '2. Are you aware of the roles and responsibilities of a Web Developer?',
#  '3. What are the added benefits of HTTP/2 compared to HTTP 1.1?',
#  '4. Can you list a few ways to speed up Page Loading?',
#  '5. How is XHTML different from HTML?',
#  '6. Explain Webpack.',
#  '7. List out newly introduced input types, APIs, form elements, and elements that support media content in HTML5.',
#  '8. State the difference between span tag and div tag in HTML5.Â\xa0',
#  '9. Explain HTML5 Web storage.',
#  '10. Explain DOM (Document Object Model).',
#  '11. What do you know about pair programming?',
#  '12. While building a web application, how do you consider SEO, maintainability, UX, performance, and security?',
#  '13. State the difference between SVG (Scalable Vector Graphics) and Canvas.',
#  '12. What is Type Coercion in JavaScript?',
#  '13. State the difference between <window.onload> and <onDocumentReady>?',
# ...

# %%
cleaned_question = [question.replace('Â\xa0', '').strip() for question in ques]

# %%
cleaned_question
# Out:
# ['1. What skills should a good Web Developer have?',
#  '2. Are you aware of the roles and responsibilities of a Web Developer?',
#  '3. What are the added benefits of HTTP/2 compared to HTTP 1.1?',
#  '4. Can you list a few ways to speed up Page Loading?',
#  '5. How is XHTML different from HTML?',
#  '6. Explain Webpack.',
#  '7. List out newly introduced input types, APIs, form elements, and elements that support media content in HTML5.',
#  '8. State the difference between span tag and div tag in HTML5.',
#  '9. Explain HTML5 Web storage.',
#  '10. Explain DOM (Document Object Model).',
#  '11. What do you know about pair programming?',
#  '12. While building a web application, how do you consider SEO, maintainability, UX, performance, and security?',
#  '13. State the difference between SVG (Scalable Vector Graphics) and Canvas.',
#  '12. What is Type Coercion in JavaScript?',
#  '13. State the difference between <window.onload> and <onDocumentReady>?',
# ...

# %%
cleaned_question[25] = '24. Explain the term "Scope" in JavaScript and write its different types.'

# %%
def remove_number(question):
    # Regular expression to match the number, dot, and space at the start
    return re.sub(r'^\d+\.\s*', '', question)

# %%
cleaned_question = [remove_number(question) for question in cleaned_question]

# %%
sample_questions = [
    "What is an API, and how is it used in web development?",
    "Explain the difference between RESTful APIs and SOAP APIs.",
    "How does CUDA enhance the performance of machine learning models?",
    "What are the key features of a well-designed REST API?",
    "Describe a scenario where you would use OAuth for authentication.",
    "How does TTS technology work, and what are its applications?",
    "What are the main advantages of using CUDA for GPU computing?",
    "Explain how an API gateway can help manage microservices.",
    "What is the difference between synchronous and asynchronous API calls?",
    "How would you secure a REST API to protect against unauthorized access?",
    "Describe the OAuth 2.0 flow and how it ensures secure access.",
    "How can TTS be integrated into a customer support chatbot?",
    "What are some challenges associated with scaling a REST API?",
    "How does CUDA enable parallel computing on NVIDIA GPUs?",
    "What are the pros and cons of using third-party APIs in your application?",
    "Explain the significance of token-based authentication in OAuth.",
    "How can TTS be used to enhance accessibility for users with disabilities?",
    "What are some common pitfalls to avoid when designing a RESTful API?",
    "How does OAuth help in delegating access without sharing passwords?",
    "What are some ways to optimize TTS performance for real-time applications?"
]

# Add sample questions to the cleaned_questions list
cleaned_question.extend(sample_questions)

# %%
# Save everything to a CSV file
import csv

# %%
with open('enhanced_questions.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Questions'])  # Header
    for question in cleaned_question:
        writer.writerow([question])

# %%
for i, sentence in enumerate(cleaned_question):
    print(sentence)
    tts = gTTS(text=sentence, lang='en')
    tts.save(f"audio_{i}.mp3")  # Save each audio clip
# Out:
# What skills should a good Web Developer have?
# Are you aware of the roles and responsibilities of a Web Developer?
# What are the added benefits of HTTP/2 compared to HTTP 1.1?
# Can you list a few ways to speed up Page Loading?
# How is XHTML different from HTML?
# Explain Webpack.
# List out newly introduced input types, APIs, form elements, and elements that support media content in HTML5.
# State the difference between span tag and div tag in HTML5.
# Explain HTML5 Web storage.
# Explain DOM (Document Object Model).
# What do you know about pair programming?
# While building a web application, how do you consider SEO, maintainability, UX, performance, and security?
# State the difference between SVG (Scalable Vector Graphics) and Canvas.
# What is Type Coercion in JavaScript?
# State the difference between <window.onload> and <onDocumentReady>?
# Describe the different kinds of HTTP requests supported by RESTful Web services.
# How does CORS work?
# What is an Entity Tag?
# ...

# %%
len(cleaned_question)
# Out:
# 93

# %%
with open('dataset.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['question', 'audio_file'])  # Header
    
    for i, sentence in enumerate(cleaned_question):
        audio_file = f'audio_{i}.mp3'  # Assuming audio files are named 1.wav, 2.wav, etc.
        writer.writerow([sentence, audio_file])

print("Dataset CSV created successfully.")
# Out:
# Dataset CSV created successfully.

# %%
from gtts import gTTS

# %%
import os
